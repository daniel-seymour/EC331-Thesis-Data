# %% [markdown]
# ##
# 1. Remove empty files and concatenate parquet files into one
# 2. Remove duplicates based on saving only the last bid based on the offer date column
# 3. Cap volume bids
# 4. Merge volume bids with generator table
# 5. Melt volume and price bids
# 6. Merge volume and price bids
# 7. Remove rows where BIDVOLUME=0
# 8. Run calculations and graphs
