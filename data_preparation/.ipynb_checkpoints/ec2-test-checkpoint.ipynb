# %%
import pandas as pd
import boto3
import io

# Fix the double slash in the path
# df = pd.read_csv('s3://thesis--ec331-s3/FCAS_RAISE1SEC-Volume-Bids/PUBLIC_DVD_BIDDAYOFFER_202310010000.CSV')

# Also fix the double slash here
s3 = boto3.client('s3')
obj = s3.get_object(Bucket='thesis--ec331-s3', Key='PUBLIC_DVD_TRADINGPRICE_202311010000.CSV')
df = pd.read_csv(io.BytesIO(obj['Body'].read()), low_memory=False)
