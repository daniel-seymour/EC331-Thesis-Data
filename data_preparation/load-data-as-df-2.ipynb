# %%
import pandas as pd

# Define the file path
file_path = '/Volumes/T7/FCAS_RAISE1SEC-Volume-Bids/PUBLIC_DVD_TRADINGPRICE_202312010000.feather'

# Read the CSV file into a DataFrame, skipping the first row
df = pd.read_feather(file_path)

# Display general information about the DataFrame
print("DataFrame Info:")
df.info()

# Show the first few rows of the DataFrame
print("\nDataFrame Head:")
print(df.head())

# Show the last few rows of the DataFrame
print("\nDataFrame Tail:")
print(df.tail())

# Display descriptive statistics for numerical columns
print("\nDataFrame Description:")
print(df.describe(include='all'))

# List all column names
print("\nDataFrame Columns:")
print(df.columns.tolist())

# Read the CSV file into a DataFrame, skipping the first row
df = pd.read_csv(file_path)

# Display general information about the DataFrame
print("DataFrame Info:")
df.info()

# Show the first few rows of the DataFrame
print("\nDataFrame Head:")
print(df.head())

# Show the last few rows of the DataFrame
print("\nDataFrame Tail:")
print(df.tail())

# Display descriptive statistics for numerical columns
print("\nDataFrame Description:")
print(df.describe(include='all'))

# List all column names
print("\nDataFrame Columns:")
print(df.columns.tolist())
# Out:
# DataFrame Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44640 entries, 0 to 44639
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   SETTLEMENTDATE  44640 non-null  object
#  1   REGIONID        44640 non-null  object
#  2   RRP             44640 non-null  float64
#  3   RAISE6SECRRP    44640 non-null  float64
#  4   RAISE60SECRRP   44640 non-null  float64
#  5   RAISE5MINRRP    44640 non-null  float64
#  6   RAISEREGRRP     44640 non-null  float64
#  7   LOWER6SECRRP    44640 non-null  float64
#  8   LOWER60SECRRP   44640 non-null  float64
#  9   LOWER5MINRRP    44640 non-null  float64
#  10  LOWERREGRRP     44640 non-null  float64
#  11  PRICE_STATUS    44640 non-null  object
# dtypes: float64(9), object(3)
# memory usage: 4.1+ MB
#
# DataFrame Head:
#         SETTLEMENTDATE REGIONID    RRP  RAISE6SECRRP  RAISE60SECRRP  \
# ...
